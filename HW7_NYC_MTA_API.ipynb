# %% [markdown]
# # HW7 API - NYC MTA API
#
# #### Authors: Ling Lin, Xuanyu Lu, Qingyang Xiao

# %% [markdown]
# - Please install "underground" package before running the code.- Please also download "stops.txt" file before running the code.

# %% [markdown]
# ### 1. Import the data from the online source
#
# To request data from the MTA, you'll also need a free API key,
# [Register here](https://api.mta.info/).
#
# Reference: https://github.com/nolanbconaway/underground

# %%
# import the necessary packages for using this API

import os

# get metadata and SubwayFeed function
from underground import metadata, SubwayFeed

# %%
API_KEY = ''    # import your registered API key
ROUTE = 'Q'   # the route information we want to see, route Q is selected as example

# get route feed
feed = SubwayFeed.get(ROUTE, api_key=API_KEY)

# %% [markdown]
# - Note: This API key only works with ungderground package v3.

# %%
# get route raw data of route Q and its expected arrival times

q_train_stops = feed.extract_stop_dict()[ROUTE]

# %%
# print q train information

q_train_stops
# Out:
# {'R17N': [datetime.datetime(2020, 4, 8, 21, 21, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 37, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 49, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 57, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 28, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 2, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R16N': [datetime.datetime(2020, 4, 8, 21, 22, 59, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 39, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 59, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 39, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R14N': [datetime.datetime(2020, 4, 8, 21, 25, 59, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 42, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 2, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 12, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 42, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 54, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'B08N': [datetime.datetime(2020, 4, 8, 21, 28, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 44, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 56, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 4, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 57, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 9, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q03N': [datetime.datetime(2020, 4, 8, 21, 30, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 46, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 58, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 6, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 27, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 37, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 47, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 59, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q04N': [datetime.datetime(2020, 4, 8, 21, 33, 59, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 10, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 20, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 40, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q05N': [datetime.datetime(2020, 4, 8, 21, 36, 59, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 4, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 15, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D39S': [datetime.datetime(2020, 4, 8, 21, 20, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 32, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 44, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 5, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 27, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D40S': [datetime.datetime(2020, 4, 8, 21, 23, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 34, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 46, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 8, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 29, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 39, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 49, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 59, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 9, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D41S': [datetime.datetime(2020, 4, 8, 21, 25, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 37, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 48, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 56, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 10, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 32, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 2, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 11, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D42S': [datetime.datetime(2020, 4, 8, 21, 27, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 39, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 58, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 12, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 44, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D43S': [datetime.datetime(2020, 4, 8, 21, 29, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 40, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 52, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 59, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 14, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 45, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 5, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D24N': [datetime.datetime(2020, 4, 8, 21, 21, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 32, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 45, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R30N': [datetime.datetime(2020, 4, 8, 21, 22, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 34, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 42, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 47, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q01N': [datetime.datetime(2020, 4, 8, 21, 30, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 42, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 43, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R20N': [datetime.datetime(2020, 4, 8, 21, 34, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 46, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 54, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 5, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 25, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 47, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 59, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D32S': [datetime.datetime(2020, 4, 8, 21, 21, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 33, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 40, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 54, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 45, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 55, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D33S': [datetime.datetime(2020, 4, 8, 21, 22, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 34, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 55, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 27, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 36, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D34S': [datetime.datetime(2020, 4, 8, 21, 24, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 36, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 43, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 57, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 9, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 38, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 48, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D35S': [datetime.datetime(2020, 4, 8, 21, 26, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 38, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 45, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 59, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 40, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 0, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D37S': [datetime.datetime(2020, 4, 8, 21, 28, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 40, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 47, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 2, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 43, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D38S': [datetime.datetime(2020, 4, 8, 21, 29, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 48, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 14, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 24, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 34, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 44, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 23, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D25S': [datetime.datetime(2020, 4, 8, 21, 21, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 28, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 42, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 14, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D26S': [datetime.datetime(2020, 4, 8, 21, 25, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 32, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 46, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 58, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 37, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 47, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D27S': [datetime.datetime(2020, 4, 8, 21, 26, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 33, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 48, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 39, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 49, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D28S': [datetime.datetime(2020, 4, 8, 21, 28, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 35, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 49, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 40, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D29S': [datetime.datetime(2020, 4, 8, 21, 29, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 36, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 2, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 12, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 32, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D30S': [datetime.datetime(2020, 4, 8, 21, 30, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 37, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 42, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 52, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D31S': [datetime.datetime(2020, 4, 8, 21, 31, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 38, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 4, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 14, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 24, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 44, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D31N': [datetime.datetime(2020, 4, 8, 21, 20, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 29, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 39, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 49, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D30N': [datetime.datetime(2020, 4, 8, 21, 22, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 30, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D29N': [datetime.datetime(2020, 4, 8, 21, 22, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 31, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 35, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D28N': [datetime.datetime(2020, 4, 8, 21, 24, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 32, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 43, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D27N': [datetime.datetime(2020, 4, 8, 21, 25, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 34, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 44, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 54, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 4, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 14, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 26, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 38, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D26N': [datetime.datetime(2020, 4, 8, 21, 27, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 35, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 28, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D25N': [datetime.datetime(2020, 4, 8, 21, 30, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 39, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 49, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 31, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D37N': [datetime.datetime(2020, 4, 8, 21, 20, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D35N': [datetime.datetime(2020, 4, 8, 21, 22, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 43, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 27, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D34N': [datetime.datetime(2020, 4, 8, 21, 24, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 5, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D33N': [datetime.datetime(2020, 4, 8, 21, 26, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 47, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 57, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D32N': [datetime.datetime(2020, 4, 8, 21, 27, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 48, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 58, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 32, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R30S': [datetime.datetime(2020, 4, 8, 21, 24, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 38, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 29, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 39, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D24S': [datetime.datetime(2020, 4, 8, 21, 25, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 40, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D43N': [datetime.datetime(2020, 4, 8, 21, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D42N': [datetime.datetime(2020, 4, 8, 21, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 42, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 52, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 4, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 16, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D41N': [datetime.datetime(2020, 4, 8, 21, 24, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 44, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D40N': [datetime.datetime(2020, 4, 8, 21, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D39N': [datetime.datetime(2020, 4, 8, 21, 28, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 48, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 58, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D38N': [datetime.datetime(2020, 4, 8, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 24, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R16S': [datetime.datetime(2020, 4, 8, 21, 22, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R17S': [datetime.datetime(2020, 4, 8, 21, 23, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 5, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R20S': [datetime.datetime(2020, 4, 8, 21, 26, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 48, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 58, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 7, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 17, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q01S': [datetime.datetime(2020, 4, 8, 21, 30, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 2, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 31, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q05S': [datetime.datetime(2020, 4, 8, 21, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 31, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 41, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 11, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q04S': [datetime.datetime(2020, 4, 8, 21, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q03S': [datetime.datetime(2020, 4, 8, 21, 25, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 35, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 45, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 55, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 5, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 15, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'B08S': [datetime.datetime(2020, 4, 8, 21, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 37, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 47, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 57, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 7, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 17, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R14S': [datetime.datetime(2020, 4, 8, 21, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 40, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 21, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 0, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 10, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 22, 20, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)]}

# %% [markdown]
# ### 2. Transform online data into python dataframe
#
# References:
# 1. https://thispointer.com/pandas-convert-dataframe-index-into-column-using-dataframe-reset_index-in-python/
# 2. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html
# 3. https://discuss.codecademy.com/t/can-we-add-a-new-column-at-a-specific-position-in-a-pandas-dataframe/355842
# 4. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %%
# import the necessary package for turning this online data into a dataframe

import pandas as pd

# %%
# Convert online data from dictionary format into python dataframe

Schedule = pd.DataFrame.from_dict(q_train_stops, orient='index')

# %%
# Uncomment to see what the original dataframe looks like

Schedule
# Out:
#                              0                         1  \
# R17N 2020-04-08 21:21:29-04:00 2020-04-08 21:37:33-04:00
# R16N 2020-04-08 21:22:59-04:00 2020-04-08 21:39:03-04:00
# R30N 2020-04-08 22:47:00-04:00                       NaT
# Q01N 2020-04-08 22:55:00-04:00                       NaT
# R20N 2020-04-08 22:59:00-04:00                       NaT
# D32S 2020-04-08 22:45:30-04:00 2020-04-08 22:55:30-04:00
# D33S 2020-04-08 22:46:30-04:00 2020-04-08 22:56:30-04:00
# D34S 2020-04-08 22:48:30-04:00 2020-04-08 22:58:30-04:00
# D35S 2020-04-08 22:50:30-04:00 2020-04-08 23:00:30-04:00
# D37S 2020-04-08 22:53:00-04:00 2020-04-08 23:03:00-04:00
# D38S 2020-04-08 22:54:00-04:00 2020-04-08 23:04:00-04:00
# D25S 2020-04-08 22:43:30-04:00                       NaT
# D26S 2020-04-08 22:47:30-04:00                       NaT
# D27S 2020-04-08 22:49:00-04:00                       NaT
# D28S 2020-04-08 22:50:30-04:00                       NaT
# D29S 2020-04-08 22:52:00-04:00                       NaT
# D30S 2020-04-08 22:52:30-04:00                       NaT
# D31S 2020-04-08 22:54:00-04:00                       NaT
# D31N                       NaT                       NaT
# D30N                       NaT                       NaT
# D29N                       NaT                       NaT
# D28N                       NaT                       NaT
# D27N                       NaT                       NaT
# D26N                       NaT                       NaT
# D25N                       NaT                       NaT
# D37N                       NaT                       NaT
# D35N                       NaT                       NaT
# D34N                       NaT                       NaT
# D33N                       NaT                       NaT
# D32N                       NaT                       NaT
# R30S                       NaT                       NaT
# D24S                       NaT                       NaT
# D43N                       NaT                       NaT
# D42N                       NaT                       NaT
# D41N                       NaT                       NaT
# D40N                       NaT                       NaT
# D39N                       NaT                       NaT
# D38N                       NaT                       NaT
# R16S                       NaT                       NaT
# R17S                       NaT                       NaT
# R20S                       NaT                       NaT
# Q01S                       NaT                       NaT
# Q05S                       NaT                       NaT
# Q04S                       NaT                       NaT
# Q03S                       NaT                       NaT
# B08S                       NaT                       NaT
# R14S                       NaT                       NaT
#
#                             10
# R17N                       NaT
# R16N                       NaT
# R14N                       NaT
# B08N                       NaT
# Q03N                       NaT
# Q04N                       NaT
# Q05N                       NaT
# D39S 2020-04-08 23:06:30-04:00
# D40S 2020-04-08 23:09:00-04:00
# D41S 2020-04-08 23:11:30-04:00
# D42S 2020-04-08 23:13:30-04:00
# D43S 2020-04-08 23:15:00-04:00
# D24N                       NaT
# R30N                       NaT
# Q01N                       NaT
# R20N                       NaT
# D32S                       NaT
# D33S                       NaT
# D34S                       NaT
# D35S                       NaT
# D37S                       NaT
# D38S                       NaT
# D25S                       NaT
# D26S                       NaT
# D27S                       NaT
# D28S                       NaT
# D29S                       NaT
# D30S                       NaT
# D31S                       NaT
# D31N                       NaT
# D30N                       NaT
# D29N                       NaT
# D28N                       NaT
# D27N                       NaT
# D26N                       NaT
# D25N                       NaT
# D37N                       NaT
# D35N                       NaT
# D34N                       NaT
# D33N                       NaT
# D32N                       NaT
# R30S                       NaT
# D24S                       NaT
# D43N                       NaT
# D42N                       NaT
# D41N                       NaT
# D40N                       NaT
# D39N                       NaT
# D38N                       NaT
# R16S                       NaT
# R17S                       NaT
# R20S                       NaT
# Q01S                       NaT
# Q05S                       NaT
# Q04S                       NaT
# Q03S                       NaT
# B08S                       NaT
# R14S                       NaT

# %%
# Add the index to be a new column in dataframe
# The original index is stop_id, so add stop_id to be a new column of dataframe

Schedule1 = Schedule.reset_index()

# Rename the newly added column as "stop_id"
Schedule2 = Schedule1.rename(columns={'index':'stop_id'})


# Read the last character of stop_id to identify the direction, N represents North, S represents South
Direction = []

for i in range(0, len(Schedule)):
    Direction.append(Schedule2.stop_id[i][-1])
        
# Direction

# Insert the new direction column to a specific postion, e.g. position 1 in this case
# Do not run this code the second time without rerun the above codes, 
# because it will appear an error if the column is already inserted 

Schedule2.insert(1, 'direction', Direction)

# Extract date information from the Timestamp column, create a new column and insert it to position 2
Schedule2.insert(2, 'date', Schedule2[0].dt.date)


# Another way of adding a new column to dataframe, but no specific position
# Schedule2['direction'] = Direction
# Schedule2['date'] = Schedule2[0].dt.date


# Replace the original Timestamp columns (Timestamp shows date and time) with time only

for j in range(0, len(Schedule2)):                # loop through rows
    for k in range(3, len(Schedule2.iloc[0])):       # loop through columns 
        if pd.notna(Schedule2.iloc[j, k]):              # Checking for missing value
            Schedule2.iloc[j, k] = pd.Timestamp.time(Schedule2.iloc[j, k])
            
            
# Another approach, work with dataframe that doesn't have NAs 
# Schedule2[0] = Schedule2[0].dt.time

# %%
# Uncomment to see what the new dataframe looks like now

Schedule2
# Out:
#    stop_id direction        date         0         1         2         3  \
# 0     R17N         N  2020-04-08  21:21:29  21:37:33  21:49:20  21:57:50
# 1     R16N         N  2020-04-08  21:22:59  21:39:03  21:50:50  21:59:20
# 2     R14N         N  2020-04-08  21:25:59  21:42:03  21:53:50  22:02:20
# 3     B08N         N  2020-04-08  21:28:29  21:44:33  21:56:20  22:04:50
# 4     Q03N         N  2020-04-08  21:30:29  21:46:33  21:58:20  22:06:50
# 5     Q04N         N  2020-04-08  21:33:59  21:50:03  22:01:50  22:10:20
# 6     Q05N         N  2020-04-08  21:36:59  21:53:03  22:04:50  22:13:20
# 7     D39S         S  2020-04-08  21:20:50  21:32:12  21:44:22  21:51:07
# 8     D40S         S  2020-04-08  21:23:20  21:34:42  21:46:37  21:53:37
# 9     D41S         S  2020-04-08  21:25:50  21:37:12  21:48:52  21:56:07
# 10    D42S         S  2020-04-08  21:27:50  21:39:12  21:50:52  21:58:07
# 11    D43S         S  2020-04-08  21:29:20  21:40:42  21:52:22  21:59:37
# 12    D24N         N  2020-04-08  21:21:03  21:32:50  21:41:20  21:51:30
# 13    R30N         N  2020-04-08  21:22:33  21:34:20  21:42:50  21:53:00
# 14    Q01N         N  2020-04-08  21:30:33  21:42:20  21:50:50  22:01:00
# 15    R20N         N  2020-04-08  21:34:33  21:46:20  21:54:50  22:05:00
# 16    D32S         S  2020-04-08  21:21:12  21:33:22  21:40:07  21:54:31
# 17    D33S         S  2020-04-08  21:22:12  21:34:22  21:41:07  21:55:31
# 18    D34S         S  2020-04-08  21:24:12  21:36:22  21:43:07  21:57:31
# 19    D35S         S  2020-04-08  21:26:12  21:38:22  21:45:07  21:59:31
# 34  22:06:00  22:16:00  22:28:00  22:40:00       NaT       NaT       NaT
# 35  22:09:30  22:19:30  22:31:30  22:43:30       NaT       NaT       NaT
# 36  22:01:00  22:13:00  22:25:00       NaT       NaT       NaT       NaT
# 37  22:03:00  22:15:00  22:27:00       NaT       NaT       NaT       NaT
# 38  22:05:00  22:17:00  22:29:00       NaT       NaT       NaT       NaT
# 39  22:07:00  22:19:00  22:31:00       NaT       NaT       NaT       NaT
# 40  22:08:00  22:20:00  22:32:00       NaT       NaT       NaT       NaT
# 41  22:10:00  22:19:30  22:29:30  22:39:30       NaT       NaT       NaT
# 42  22:11:30  22:21:00  22:31:00  22:41:00       NaT       NaT       NaT
# 43  22:03:00  22:15:00       NaT       NaT       NaT       NaT       NaT
# 44  22:04:30  22:16:30       NaT       NaT       NaT       NaT       NaT
# 45  22:06:00  22:18:00       NaT       NaT       NaT       NaT       NaT
# 46  22:08:00  22:20:00       NaT       NaT       NaT       NaT       NaT
# 47  22:10:00  22:22:00       NaT       NaT       NaT       NaT       NaT
# 48  22:12:00  22:24:00       NaT       NaT       NaT       NaT       NaT
# 49  22:03:30  22:13:30  22:23:30       NaT       NaT       NaT       NaT
# 50  22:05:00  22:15:00  22:25:00       NaT       NaT       NaT       NaT
# 51  22:07:30  22:17:30  22:27:30       NaT       NaT       NaT       NaT
# 52  22:11:30  22:21:30  22:31:30       NaT       NaT       NaT       NaT
# 53  22:01:30  22:11:30       NaT       NaT       NaT       NaT       NaT
# 54  22:03:30  22:13:30       NaT       NaT       NaT       NaT       NaT
# 55  22:05:30  22:15:30       NaT       NaT       NaT       NaT       NaT
# 56  22:07:30  22:17:30       NaT       NaT       NaT       NaT       NaT
# 57  22:10:30  22:20:30       NaT       NaT       NaT       NaT       NaT

# %% [markdown]
# ### 3. Data Visulization
#
# References:
# - https://stackoverflow.com/questions/43757820/how-to-add-a-variable-to-python-plt-title
# - https://stackoverflow.com/questions/14432557/matplotlib-scatter-plot-with-different-text-at-each-data-point

# %%
from datetime import date
from datetime import datetime

# Use a "magic command" to specify how we want our plots displayed
# %matplotlib notebook show dynamic/interactive plot

# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plot 1: This plot illustrates time lag  in minutes for nearest top 10 stops.

# %%
# Rename Schedule dataframe as sch_df
sch_df = Schedule2

# show top 10 time nearest station info
sch_df.head(10)

for i in range(10):
    sch_df.iloc[i]['stop_id']
    
# find top 10 time nearest stops
stop = []
for i in range(20):
    stop.append(sch_df.iloc[i]['stop_id'])

print(stop)
# stop = [sch_df.iloc[0]['stop_id'],sch_df.iloc[1]['stop_id']]
# stop = list.append('sch_df.iloc[0]['stop_id']')
# Out:
# ['R17N', 'R16N', 'R14N', 'B08N', 'Q03N', 'Q04N', 'Q05N', 'D39S', 'D40S', 'D41S', 'D42S', 'D43S', 'D24N', 'R30N', 'Q01N', 'R20N', 'D32S', 'D33S', 'D34S', 'D35S']

# %%
# !more stops.txt

# %%
# Read the text file that contains stops information 

coord_df = pd.read_csv('stops.txt')
print(coord_df)
# Out:
#      stop_id  stop_code                    stop_name  stop_desc   stop_lat  \
# 0        101        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 1       101N        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 2       101S        NaN  Van Cortlandt Park - 242 St        NaN  40.889248
# 3        103        NaN                       238 St        NaN  40.884667
# 4       103N        NaN                       238 St        NaN  40.884667
# ...      ...        ...                          ...        ...        ...
# 1498    S30N        NaN                Tompkinsville        NaN  40.636949
# 1499    S30S        NaN                Tompkinsville        NaN  40.636949
# 1500     S31        NaN                    St George        NaN  40.643748
# 1501    S31N        NaN                    St George        NaN  40.643748
# 1502    S31S        NaN                    St George        NaN  40.643748
#
#        stop_lon  zone_id  stop_url  location_type parent_station
# 0    -73.898583      NaN       NaN              1            NaN
# 1    -73.898583      NaN       NaN              0            101
# 2    -73.898583      NaN       NaN              0            101
# 3    -73.900870      NaN       NaN              1            NaN
# 4    -73.900870      NaN       NaN              0            103
# ...         ...      ...       ...            ...            ...
# 1498 -74.074835      NaN       NaN              0            S30
# 1499 -74.074835      NaN       NaN              0            S30
# 1500 -74.073643      NaN       NaN              1            NaN
# 1501 -74.073643      NaN       NaN              0            S31
# 1502 -74.073643      NaN       NaN              0            S31
#
# [1503 rows x 10 columns]

# %%
# find stops name

stop_name = []
for i in range(10):
    stop_name.append(coord_df.loc[coord_df['stop_id'] == stop[i],'stop_name'].values[0][0:20])
print(stop_name)


# find latitude and longtitude of these 10 stops

x_lat = []
for i in range(10):
    x_lat.append(coord_df.loc[coord_df['stop_id'] == stop[i],'stop_lat'].values[0])
print(x_lat)


# find longtitude of these 10 stops

x_lon = []
for i in range(10):
    x_lon.append(coord_df.loc[coord_df['stop_id'] == stop[i],'stop_lon'].values[0])
print(x_lon)
# Out:
# ['34 St - Herald Sq', 'Times Sq - 42 St', '57 St - 7 Av', 'Lexington Av/63 St', '72 St', '86 St', '96 St', 'Sheepshead Bay', 'Brighton Beach', 'Ocean Pkwy']
# [40.749567, 40.754672, 40.764664, 40.764629, 40.768799, 40.777891, 40.784318, 40.586896, 40.577621, 40.576312]
# [-73.98795, -73.986754, -73.98065799999999, -73.966113, -73.958424, -73.951787, -73.947152, -73.954155, -73.961376, -73.968501]

# %%
# calculate nearest waiting time btw top 2 trains in minutes for this train at these 10 stops
# sch_df.iloc[0].values[3]

# time_st = mean(sch_df.iloc[i].values[3])

lag_min = []

for i in range(10):
    dt1 = datetime.combine(date.today(), sch_df.iloc[i].values[3])
    dt2 = datetime.combine(date.today(), sch_df.iloc[i].values[4])
    #dt3 = datetime.combine(date.today(), sch_df.iloc[i].values[5])
    #lag_min = ((dt2 - dt1).total_seconds()+(dt3 - dt2).total_seconds())/2
    #lag_min = (dt2 - dt1).total_seconds()/60
    sec1 = dt2 - dt1
    lag = sec1.total_seconds()/60
    #print (lag_min)
    lag_min.append(lag)
    
print(lag_min)
# Out:
# [16.066666666666666, 16.066666666666666, 16.066666666666666, 16.066666666666666, 16.066666666666666, 16.066666666666666, 16.066666666666666, 11.366666666666667, 11.366666666666667, 11.366666666666667]

# %%
def trible (lst):
    return [i*5 for i in lst]
lag_t = trible(lag_min)

# %%
plt.title ('Time Lag (minutes) for nearest top 10 stops')

# plt.scatter (x_lat, x_lon, s = lag_min);

# different color
colors = []
for i in range (10):
    colors.append( 1/ (lag_min [i]/float(max(lag_min))) )

plt.scatter(x_lat, x_lon, s = lag_t, c=colors , alpha =1);

# Color of the circle: Lighter the color, lower the time lag
# Size of the circle: Smaller the circle, lower the time lag


# add text
for i in range (10):
    myx = x_lat[i]
    myy = x_lon[i]
    mystop = stop_name [i]
    plt. text (myx , myy , mystop , color ="red", fontsize =7,horizontalalignment='left',verticalalignment='top')
    
# x and y labels
plt.ylabel('Station Longtitude')
plt.xlabel('Station Latitude')

# Save plot as a png. image
plt.savefig('TimeLag.png')

#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# #### Plot 2: This plot illustrates the time gap between train arrivals for a pre-identified stop.

# %%
# Identify the stop_id that we wish to search
# In this case, we use stop 'Q05N' as the pre-identified stop

id = 'Q05N'

# %%
# Find the index that associates with the corresponding stop
index = int(Schedule2.index[Schedule2['stop_id'] == id].values)

# Find the schedule of that stop
times = Schedule2.iloc[index]

# Drop the NAs in the data
y = times.dropna()[3::]

# Set the x-values
x = range(0, len(y), 1)

# %%
# Plot times data using matplotlib
pd.plotting.register_matplotlib_converters()

# Plot size
plt.figure(figsize=(8, 5))

# Plot title
plt.title('Train Arrival Schedule of Stop: '+str(id)+' on '+str(times['date']))

# x and y labels
plt.ylabel('Time of Arrivals')
plt.xlabel('Arrivals')

# Line plot
plt.plot(x, y, 'go-')

# Lable points
for i, txt in enumerate(y):
    plt.annotate(txt, (x[i]+0.3, y[i]))

# Save plot as a png. image
plt.savefig('MTA_TimeGap.png')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %% [markdown]
# #### Plot 3: This plot illustrates the average time interval of Q train stops in seconds.
# - Showing the busyness of the stops

# %%
# Select Q train stops from the dataframe and put it into a new dataframe q_schedule
index_list = list(Schedule.index)
index_q = []

# Loop through to select stops belong to Q train
for q in index_list:
    if 'Q' in q:
        index_q.append(q)
q_schedule = Schedule.loc[index_q, :]

# %%
# Calculate time interval of all stops
time_interval = []
for i in range(len(q_schedule.columns)-1):
    time_interval.append(list(q_schedule[i+1] - q_schedule[i]))

# Convert time intervals from timedelta format to seconds
for a in range(len(time_interval)):
    for b in range(len(time_interval[a])):
        time_interval[a][b] = time_interval[a][b].total_seconds()

# Convert time interval data from lists to dataframe
time_interval_df = pd.DataFrame(time_interval)

# Calculate the average time interval of all stops
average_time_interval = list(time_interval_df.mean())
q_schedule['Average Time Interval'] = average_time_interval

# Show the new dataframe
q_schedule
# Out:
#                              0                         1  \
# Q03N 2020-04-08 21:30:29-04:00 2020-04-08 21:46:33-04:00
# Q04N 2020-04-08 21:33:59-04:00 2020-04-08 21:50:03-04:00
# Q05N 2020-04-08 21:36:59-04:00 2020-04-08 21:53:03-04:00
# Q01N 2020-04-08 21:30:33-04:00 2020-04-08 21:42:20-04:00
# Q01S 2020-04-08 21:30:31-04:00 2020-04-08 21:42:00-04:00
# Q05S 2020-04-08 21:21:30-04:00 2020-04-08 21:31:30-04:00
# Q04S 2020-04-08 21:23:30-04:00 2020-04-08 21:33:30-04:00
# Q03S 2020-04-08 21:25:30-04:00 2020-04-08 21:35:30-04:00
#
#                              2                         3  \
# Q03N 2020-04-08 21:58:20-04:00 2020-04-08 22:06:50-04:00
# Q04N 2020-04-08 22:01:50-04:00 2020-04-08 22:10:20-04:00
# Q05N 2020-04-08 22:04:50-04:00 2020-04-08 22:13:20-04:00
# Q01N 2020-04-08 21:50:50-04:00 2020-04-08 22:01:00-04:00
# Q01S 2020-04-08 21:52:00-04:00 2020-04-08 22:02:00-04:00
# Q05S 2020-04-08 21:41:30-04:00 2020-04-08 21:51:30-04:00
# Q04S 2020-04-08 21:43:30-04:00 2020-04-08 21:53:30-04:00
# Q03S 2020-04-08 21:45:30-04:00 2020-04-08 21:55:30-04:00
#
#                              4                         5  \
# Q03N 2020-04-08 22:17:00-04:00 2020-04-08 22:27:00-04:00
# Q04N 2020-04-08 22:20:30-04:00 2020-04-08 22:30:30-04:00
# Q05N 2020-04-08 22:23:30-04:00 2020-04-08 22:33:30-04:00
# Q01N 2020-04-08 22:11:00-04:00 2020-04-08 22:21:30-04:00
# Q01S 2020-04-08 22:11:30-04:00 2020-04-08 22:21:30-04:00
# Q05S 2020-04-08 22:01:30-04:00 2020-04-08 22:11:30-04:00
# Q04S 2020-04-08 22:03:30-04:00 2020-04-08 22:13:30-04:00
# Q03S 2020-04-08 22:05:30-04:00 2020-04-08 22:15:30-04:00
#
#                              6                         7  \
# Q03N 2020-04-08 22:37:30-04:00 2020-04-08 22:47:00-04:00
# Q04N 2020-04-08 22:40:45-04:00 2020-04-08 22:50:30-04:00
# Q05N 2020-04-08 22:43:30-04:00 2020-04-08 22:53:30-04:00
# Q01N 2020-04-08 22:31:00-04:00 2020-04-08 22:43:00-04:00
# Q01S 2020-04-08 22:31:30-04:00                       NaT
# Q05S                       NaT                       NaT
# Q04S                       NaT                       NaT
# Q03S                       NaT                       NaT
#
#                              8                         9  10  \
# Q03N 2020-04-08 22:59:00-04:00 2020-04-08 23:11:00-04:00 NaT
# Q04N 2020-04-08 23:01:30-04:00 2020-04-08 23:13:30-04:00 NaT
# Q05N 2020-04-08 23:03:30-04:00 2020-04-08 23:15:30-04:00 NaT
# Q01N 2020-04-08 22:55:00-04:00                       NaT NaT
# Q01S                       NaT                       NaT NaT
# Q05S                       NaT                       NaT NaT
# Q04S                       NaT                       NaT NaT
# Q03S                       NaT                       NaT NaT
#
#       Average Time Interval
# Q03N             670.111111
# Q04N             663.444444
# Q05N             656.777778
# Q01N             633.375000
# Q01S             609.833333
# Q05S             600.000000
# Q04S             600.000000
# Q03S             600.000000

# %%
# Set labels and x axis of the plot
labels = list(q_schedule.index)
x = range(len(labels))

# Plot the Average Time Interval for different Q train stops
fig, ax = plt.subplots()

# mark title, x and y axis labels
plt.bar(x, average_time_interval )
plt.xticks(x, labels)
ax.set_ylabel('Average Time Interval (sec.)')
ax.set_xlabel('Stops')
ax.set_title('Average Time Interval for Q Train Stops');

# Save plot as a png. image
plt.savefig('MTA_ATI.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
