# %% [markdown]
# # HW7 API - NYC MTA API
#
# #### Authors: Ling Lin, Xuanyu Lu, Qingyang Xiao

# %% [markdown]
# ### 1. Import the data from the online source
#
# To request data from the MTA, you'll also need a free API key,
# [Register here](https://api.mta.info/).
#
# Reference: https://github.com/nolanbconaway/underground

# %%
# import the necessary packages for using this API

import os

# get metadata and SubwayFeed function
from underground import metadata, SubwayFeed

# %%
API_KEY = '5H3pxsm5LT8OwtBs9LWoWaNGf0j67zER1dxQL214'    # API key
ROUTE = 'Q'   # the route information we want to see, route Q is selected as example

# get route feed
feed = SubwayFeed.get(ROUTE, api_key=API_KEY)

# %%
# get route raw data of route Q and its expected arrival times

q_train_stops = feed.extract_stop_dict()[ROUTE]

# %%
# print q train information

q_train_stops
# Out:
# {'D41S': [datetime.datetime(2020, 4, 8, 17, 26, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 28, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 54, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 1, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 10, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 44, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 54, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 14, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D42S': [datetime.datetime(2020, 4, 8, 17, 28, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 30, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 56, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 3, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 12, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 16, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D43S': [datetime.datetime(2020, 4, 8, 17, 30, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 32, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 57, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 4, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 14, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 48, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 58, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q03N': [datetime.datetime(2020, 4, 8, 17, 26, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 47, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 1, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 49, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 19, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 8, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 18, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q04N': [datetime.datetime(2020, 4, 8, 17, 28, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 50, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 4, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 37, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 22, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 1, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 11, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 21, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q05N': [datetime.datetime(2020, 4, 8, 17, 30, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 52, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 6, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 39, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 24, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D40S': [datetime.datetime(2020, 4, 8, 17, 26, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 51, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 59, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 8, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 28, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 42, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 52, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 26, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q01N': [datetime.datetime(2020, 4, 8, 17, 30, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 44, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 2, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 2, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R20N': [datetime.datetime(2020, 4, 8, 17, 35, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 49, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 7, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R17N': [datetime.datetime(2020, 4, 8, 17, 38, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 52, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 10, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 49, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R16N': [datetime.datetime(2020, 4, 8, 17, 40, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 54, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 41, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 12, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R14N': [datetime.datetime(2020, 4, 8, 17, 43, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 57, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 44, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 15, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 14, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'B08N': [datetime.datetime(2020, 4, 8, 17, 45, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 59, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 47, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 17, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 16, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D26S': [datetime.datetime(2020, 4, 8, 17, 27, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 35, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 45, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 5, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 19, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 49, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D27S': [datetime.datetime(2020, 4, 8, 17, 29, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 37, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 47, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 5, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D28S': [datetime.datetime(2020, 4, 8, 17, 30, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 38, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 48, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 32, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D29S': [datetime.datetime(2020, 4, 8, 17, 32, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 40, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 50, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 24, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D30S': [datetime.datetime(2020, 4, 8, 17, 33, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 41, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 50, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 10, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 24, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 34, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 54, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 9, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D31S': [datetime.datetime(2020, 4, 8, 17, 35, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 43, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 52, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 12, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 26, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 36, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 10, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D32S': [datetime.datetime(2020, 4, 8, 17, 36, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 44, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 54, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 14, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 28, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 57, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D33S': [datetime.datetime(2020, 4, 8, 17, 37, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 45, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 55, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 39, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 13, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D34S': [datetime.datetime(2020, 4, 8, 17, 39, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 47, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 57, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 0, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D35S': [datetime.datetime(2020, 4, 8, 17, 42, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 50, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 59, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 17, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D37S': [datetime.datetime(2020, 4, 8, 17, 45, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 17, 53, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 2, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 36, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 18, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 8, 19, 20, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  '
# D32S                       NaT                       NaT
# D33S                       NaT                       NaT
# D34S                       NaT                       NaT
# D35S                       NaT                       NaT
# D37S                       NaT                       NaT
# D38S                       NaT                       NaT
# D39S                       NaT                       NaT
# D28N                       NaT                       NaT
# D27N                       NaT                       NaT
# D26N                       NaT                       NaT
# D25N                       NaT                       NaT
# D24N                       NaT                       NaT
# R30N                       NaT                       NaT
# R30S                       NaT                       NaT
# D24S                       NaT                       NaT
# D25S                       NaT                       NaT
# Q01S                       NaT                       NaT
# Q05S                       NaT                       NaT
# Q04S                       NaT                       NaT
# Q03S                       NaT                       NaT
# B08S                       NaT                       NaT
# R14S                       NaT                       NaT
# R16S                       NaT                       NaT
# R17S                       NaT                       NaT
# R20S                       NaT                       NaT
# D43N                       NaT                       NaT
# D42N                       NaT                       NaT
# D41N                       NaT                       NaT
# D40N                       NaT                       NaT
# D39N                       NaT                       NaT
# D38N                       NaT                       NaT
# D37N                       NaT                       NaT
# D35N                       NaT                       NaT
# D34N                       NaT                       NaT
# D33N                       NaT                       NaT
# D32N                       NaT                       NaT
# D31N                       NaT                       NaT
# D30N                       NaT                       NaT
# D29N                       NaT                       NaT

# %%
# Add the index to be a new column in dataframe
# The original index is stop_id, so add stop_id to be a new column of dataframe

Schedule1 = Schedule.reset_index()

# Rename the newly added column as "stop_id"
Schedule2 = Schedule1.rename(columns={'index':'stop_id'})


# Read the last character of stop_id to identify the direction, N represents North, S represents South
Direction = []

for i in range(0, len(Schedule)):
    Direction.append(Schedule2.stop_id[i][-1])
        
# Direction

# Insert the new direction column to a specific postion, e.g. position 1 in this case
# Do not run this code the second time without rerun the above codes, 
# because it will appear an error if the column is already inserted 

Schedule2.insert(1, 'direction', Direction)

# Extract date information from the Timestamp column, create a new column and insert it to position 2
Schedule2.insert(2, 'date', Schedule2[0].dt.date)


# Another way of adding a new column to dataframe, but no specific position
# Schedule2['direction'] = Direction
# Schedule2['date'] = Schedule2[0].dt.date


# Replace the original Timestamp columns (Timestamp shows date and time) with time only

for j in range(0, len(Schedule2)):                # loop through rows
    for k in range(3, len(Schedule2.iloc[0])):       # loop through columns 
        if pd.notna(Schedule2.iloc[j, k]):              # Checking for missing value
            Schedule2.iloc[j, k] = pd.Timestamp.time(Schedule2.iloc[j, k])
            
            
# Another approach, work with dataframe that doesn't have NAs 
# Schedule2[0] = Schedule2[0].dt.time

# %%
# Uncomment to see what the new dataframe looks like now

Schedule2
# Out:
#    stop_id direction        date         0         1         2         3  \
# 0     Q05N         N  2020-04-08  16:36:26  16:50:26  17:06:56  17:23:26
# 1     D41S         S  2020-04-08  16:36:31  16:50:21  17:07:56  17:24:34
# 2     D42S         S  2020-04-08  16:38:31  16:52:21  17:09:56  17:26:34
# 3     D43S         S  2020-04-08  16:40:01  16:53:51  17:11:26  17:28:04
# 4     R17N         N  2020-04-08  16:36:56  16:53:26  17:09:56  17:19:41
# 5     R16N         N  2020-04-08  16:38:26  16:54:56  17:11:26  17:21:11
# 23  17:41:00  17:51:00  18:02:00  18:11:00       NaT       NaT
# 24  17:42:00  17:52:00  18:03:00  18:12:00       NaT       NaT
# 25  17:44:00  17:54:00  18:05:00  18:14:00       NaT       NaT
# 26  17:44:30  17:54:30  18:05:30  18:14:30       NaT       NaT
# 27  17:46:30  17:56:30  18:07:30  18:16:30       NaT       NaT
# 28  17:48:00  17:58:00  18:09:00  18:18:00       NaT       NaT
# 29  17:49:00  17:59:00  18:10:00  18:19:00       NaT       NaT
# 30  17:37:30  17:47:30       NaT       NaT       NaT       NaT
# 31  17:39:00  17:49:00       NaT       NaT       NaT       NaT
# 32  17:40:00  17:50:00       NaT       NaT       NaT       NaT
# 33  17:41:30  17:51:30       NaT       NaT       NaT       NaT
# 34  17:42:30  17:52:30       NaT       NaT       NaT       NaT
# 35  17:44:00  17:54:00       NaT       NaT       NaT       NaT
# 36  17:45:30  17:55:30       NaT       NaT       NaT       NaT
# 37  17:47:00  17:57:00       NaT       NaT       NaT       NaT
# 38  17:51:00  18:01:00       NaT       NaT       NaT       NaT
# 39  17:25:00  17:35:00  17:45:00       NaT       NaT       NaT
# 40  17:28:00  17:38:00  17:48:00       NaT       NaT       NaT
# 41  17:32:00  17:42:30  17:52:00       NaT       NaT       NaT
# 42  17:40:30  17:51:30  18:00:30       NaT       NaT       NaT
# 43  17:38:00       NaT       NaT       NaT       NaT       NaT
# 44  17:40:00       NaT       NaT       NaT       NaT       NaT
# 45  17:41:00       NaT       NaT       NaT       NaT       NaT
# 46  17:43:30       NaT       NaT       NaT       NaT       NaT
# 47  17:46:00       NaT       NaT       NaT       NaT       NaT
# 48  17:25:30  17:35:30       NaT       NaT       NaT       NaT
# 49  17:27:30  17:37:30       NaT       NaT       NaT       NaT
# 50  17:30:30  17:40:30       NaT       NaT       NaT       NaT
# 51  17:33:30  17:43:30       NaT       NaT       NaT       NaT
# 52       NaT       NaT       NaT       NaT       NaT       NaT
# 53       NaT       NaT       NaT       NaT       NaT       NaT
# 54       NaT       NaT       NaT       NaT       NaT       NaT
# 55       NaT       NaT       NaT       NaT       NaT       NaT
# 56  17:31:30       NaT       NaT       NaT       NaT       NaT
# 57  17:33:30       NaT       NaT       NaT       NaT       NaT

# %% [markdown]
# ### 3. Data Visulization
#
# References:
# - https://stackoverflow.com/questions/43757820/how-to-add-a-variable-to-python-plt-title
# - https://stackoverflow.com/questions/14432557/matplotlib-scatter-plot-with-different-text-at-each-data-point

# %%
from datetime import date
from datetime import datetime

# Use a "magic command" to specify how we want our plots displayed
# %matplotlib notebook show dynamic/interactive plot

# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plot 1: This plot illustrates time lag  in minutes for nearest top 10 stops.

# %%
# Rename Schedule dataframe as sch_df
sch_df = Schedule2

# show top 10 time nearest station info
sch_df.head(10)

for i in range(10):
    sch_df.iloc[i]['stop_id']
    
# find top 10 time nearest stops
stop = []
for i in range(20):
    stop.append(sch_df.iloc[i]['stop_id'])

print(stop)
# stop = [sch_df.iloc[0]['stop_id'],sch_df.iloc[1]['stop_id']]
# stop = list.append('sch_df.iloc[0]['stop_id']')
# Out:
# ['D41S', 'D42S', 'D43S', 'Q03N', 'Q04N', 'Q05N', 'D40S', 'Q01N', 'R20N', 'R17N', 'R16N', 'R14N', 'B08N', 'D26S', 'D27S', 'D28S', 'D29S', 'D30S', 'D31S', 'D32S']

# %%
# !more stops.txt
# Out:
# n_type,parent_station
# 101,,Van Cortlandt Park - 242 St,,40.889248,-73.898583,,,1,
# 101N,,Van Cortlandt Park - 242 St,,40.889248,-73.898583,,,0,101
# 101S,,Van Cortlandt Park - 242 St,,40.889248,-73.898583,,,0,101
# 103,,238 St,,40.884667,-73.90087,,,1,
# 103N,,238 St,,40.884667,-73.90087,,,0,103
# 103S,,238 St,,40.884667,-73.90087,,,0,103
# 104,,231 St,,40.878856,-73.904834,,,1,
# 104N,,231 St,,40.878856,-73.904834,,,0,104
# 104S,,231 St,,40.878856,-73.904834,,,0,104
# 106,,Marble Hill - 225 St,,40.874561,-73.909831,,,1,
# 106N,,Marble Hill - 225 St,,40.874561,-73.909831,,,0,106
# 106S,,Marble Hill - 225 St,,40.874561,-73.909831,,,0,106
# 107,,215 St,,40.869444,-73.915279,,,1,
# 107N,,215 St,,40.869444,-73.915279,,,0,107
# 107S,,215 St,,40.869444,-73.915279,,,0,107
# 108,,207 St,,40.864621,-73.918822,,,1,
# 108N,,207 St,,40.864621,-73.918822,,,0,108
# 108S,,207 St,,40.864621,-73.918822,,,0,108
# 109,,Dyckman St,,40.860531,-73.925536,,,1,
# 109N,,Dyckman St,,40.860531,-73.925536,,,0,109
# 109S,,Dyckman St,,40.860531,-73.925536,,,0,109
# stops.txt

# %%
# Read the text file that contains stops information 

coord_df = pd.read_csv('stops.txt')
print(coord_df)

# %%
# find stops name

stop_name = []
for i in range(10):
    stop_name.append(coord_df.loc[coord_df['stop_id'] == stop[i],'stop_name'].values[0][0:20])
print(stop_name)


# find latitude and longtitude of these 10 stops

x_lat = []
for i in range(10):
    x_lat.append(coord_df.loc[coord_df['stop_id'] == stop[i],'stop_lat'].values[0])
print(x_lat)


# find longtitude of these 10 stops

x_lon = []
for i in range(10):
    x_lon.append(coord_df.loc[coord_df['stop_id'] == stop[i],'stop_lon'].values[0])
print(x_lon)

# %%
# calculate nearest waiting time btw top 2 trains in minutes for this train at these 10 stops
# sch_df.iloc[0].values[3]

# time_st = mean(sch_df.iloc[i].values[3])

lag_min = []

for i in range(10):
    dt1 = datetime.combine(date.today(), sch_df.iloc[i].values[3])
    dt2 = datetime.combine(date.today(), sch_df.iloc[i].values[4])
    #dt3 = datetime.combine(date.today(), sch_df.iloc[i].values[5])
    #lag_min = ((dt2 - dt1).total_seconds()+(dt3 - dt2).total_seconds())/2
    #lag_min = (dt2 - dt1).total_seconds()/60
    sec1 = dt2 - dt1
    lag = sec1.total_seconds()/60
    #print (lag_min)
    lag_min.append(lag)
    
print(lag_min)

# %%
plt.title ('Time Lag (minutes) for nearest top 10 stops')

# plt.scatter (x_lat, x_lon, s = lag_min);

# different color
colors = []
for i in range (10):
    colors . append ( lag_min [i]/float(max(lag_min)))

plt.scatter(x_lat, x_lon ,s = lag_min, c=colors , alpha =1);

# add text
for i in range (10):
    myx = x_lat[i]
    myy = x_lon[i]
    mystop = stop_name [i]
    plt. text (myx , myy , mystop , color ="red", fontsize =7,horizontalalignment='left',verticalalignment='top')
    
# x and y labels
plt.ylabel('Station Longtitude')
plt.xlabel('Station Latitude')

# Save plot as a png. image
plt.savefig('TimeLag.png')

plt.show()

# %% [markdown]
# #### Plot 2: This plot illustrates the time gap between train arrivals for a pre-identified stop.

# %%
# Identify the stop_id that we wish to search
# In this case, we use stop 'Q05N' as the pre-identified stop

id = 'Q05N'

# %%
# Find the index that associates with the corresponding stop
index = int(Schedule2.index[Schedule2['stop_id'] == id].values)

# Find the schedule of that stop
times = Schedule2.iloc[index]

# Drop the NAs in the data
y = times.dropna()[3::]

# Set the x-values
x = range(0, len(y), 1)

# %%
# Plot times data using matplotlib
pd.plotting.register_matplotlib_converters()

# Plot size
plt.figure(figsize=(8, 5))

# Plot title
plt.title('Train Arrival Schedule of Stop: '+str(id)+' on '+str(times['date']))

# x and y labels
plt.ylabel('Time of Arrivals')
plt.xlabel('Arrivals')

# Line plot
plt.plot(x, y, 'go-')

# Lable points
for i, txt in enumerate(y):
    plt.annotate(txt, (x[i]+0.3, y[i]))

# Save plot as a png. image
plt.savefig('MTA_TimeGap.png')

# %% [markdown]
# #### Plot 3: This plot illustrates the average time interval of Q train stops in seconds.
# - Showing the busyness of the stops

# %%
# Select Q train stops from the dataframe and put it into a new dataframe q_schedule
index_list = list(Schedule.index)
index_q = []

# Loop through to select stops belong to Q train
for q in index_list:
    if 'Q' in q:
        index_q.append(q)
q_schedule = Schedule.loc[index_q, :]

# %%
# Calculate time interval of all stops
time_interval = []
for i in range(len(q_schedule.columns)-1):
    time_interval.append(list(q_schedule[i+1] - q_schedule[i]))

# Convert time intervals from timedelta format to seconds
for a in range(len(time_interval)):
    for b in range(len(time_interval[a])):
        time_interval[a][b] = time_interval[a][b].total_seconds()

# Convert time interval data from lists to dataframe
time_interval_df = pd.DataFrame(time_interval)

# Calculate the average time interval of all stops
average_time_interval = list(time_interval_df.mean())
q_schedule['Average Time Interval'] = average_time_interval

# Show the new dataframe
q_schedule

# %%
# Set labels and x axis of the plot
labels = list(q_schedule.index)
x = range(len(labels))

# Figure size
plt.figure(figsize=(6, 4))

# Plot the Average Time Interval for different Q train stops
# fig, ax = plt.subplots()

# mark title, x and y axis labels
plt.bar(x, average_time_interval)
plt.xticks(x, labels)
ax.set_ylabel('Average Time Interval (sec.)')
ax.set_xlabel('Stops')
ax.set_title('Average Time Interval for Q Train Stops');

# Save plot as a png. image
plt.savefig('MTA_ATI.png')
